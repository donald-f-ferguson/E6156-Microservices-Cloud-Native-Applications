// %% [markdown]
// <b><center>
// <span style="font-size: 24pt; line-height: 1.2">
// Topics in SW Engineering: Cloud Native Applications
// </span>
// </center></b>
// </span><br>
// <p>
// <i><center>
// <span style="font-size: 20pt; line-height: 1.2">
// Lecture 1: Introduction and Overview
// </span>
// </center></i>

// %% [markdown]
// # Today's Lecture
//
// 1. Logistics:
//     - Course overview and agenda
//     - Structure, lectures, meetings
//     - Grading, assignments, ...
// <br><br>
// 1. Definition and overview of concepts:
//     - Microservices
//     - Cloud: IaaS, SaaS, PaaS, MBaaS, APIaaS, FaaS, ...
//     - APIs: API management/gateways, using APIs.
//     - Content distribution networks.
//     - Message-Drive-Architectures, Event-Driven-Architectures.
//     - REST.
//     - OAuth2, social media integration.
//     - Multi-tenancy.
//     - SQL, NoSQL, Graph, ..., cloud databases.
//     - Service orchestration.
//     - Application and systems management.
//     - Application development best practices.
//     - Infrastructure as code.
// <br><br>
// 1. Target application we will attempt to build.
// <br><br>
// 1. Foundational topics:
//     - Asynchronous programming and promises.
//     - Connections, connectors, ...
// <br><br>
// 1. First steps on first microservice.

// %% [markdown]
// # Course Overview, Structure and Logistics
//
// ## About your Instructor
//
// - _Professor of Professional Practice,_ Dept. of Computer Science.
//     - 624 Shapiro/CEPSR
//     - dff9@columbia.edu
//
//
// - Academic experience
//     - Ph.D. in Computer Science, Columbia University, 1989.
//     - Full time _Professor of Professional Practice_, 01-Jan-2018 ro 31-Dec-2019.
//     - Currently adjunct professors, with 10 previous semesters as an adjunct professor teaching
//         - _E6998: Topics in Computer Science_, E6156: Topics in SW Engineering
//             - Cloud Computing
//             - Web and Internet Application Development
//             - Web Application Servers and Applications
//             - Microservices
//         - _W4111 - Introduction to Databases_
//         - _E1006 - Introduction to Computing for Engineers and Applied Scientists using Python_
//
//
// - 35 years industry experience
//     - [IBM Fellow](https://en.wikipedia.org/wiki/IBM_Fellow), Chief Architect for [IBM Software Group](https://en.wikipedia.org/wiki/IBM_Software_Group_(SWG)
//     - Microsoft Technical Fellow
//     - Executive Vice President, Chief Technology Officer, [CA Technologies](https://www.ca.com/us.html)
//     - Vice President, CTO, Senior Fellow, [Dell Software Group](https://en.wikipedia.org/wiki/Dell_Software)
//     - Co-Founder and CTO, [Seeka TV](https://seekatv.com/)
//
//
// - Publications
//     - Approximately 60 technical publications.
//     - Authored, co-authored several standards in web applications and web services.
//     - 12 patents.
//
//
// - Personal and hobbies
//     - Two amazing daughters (One is Barnard student. One is a senior in high school).
//     - Interested in languages. Speak Spanish reasonably well and trying to learn Arabic.
//     - Black Belt in Kenpo Karate. Taken Krav Maga.
//     - Amateur astronomer.
//     - Road bicycling.
//     - Officer in the New York Guard.
//
// <br>
//
// |<img src="../../images/aboutme.jpeg">|
// |:---:|
// |__About Me__|

// %% [markdown]
// ## Objectives
//
// - We will form small teams and build a simple, realistic microservice/cloud application.
//
//
// - Course objectives:
//     - Practical experience with modern technology for building solutions.
//     - Be able to say that you have built a microservice/cloud application and cite a list of technology used.
//     - Become a better programmer through experience with patterns and best practices. My experience has been that most students write "crappy code."
//     - Prepare you for internships and jobs.
//     - Have seriously cool stuff to put on your resume and discuss on interviews.

// %% [markdown]
// ## Coursework
//
// - Build a simple multi-tenant cloud application in a small team (5 people):
//     - A set of microservices.
//     - Using elements of cloud computing:
//
//
// - Periodically demo, present and have an architecture review.
//
//
// - Sort of like a small startup, only with a bit more formal reviews.

// %% [markdown]
// ### Course Format, Grading and Environment
//
// - Lectures: Friday, 1:10pm to 3:40pm; 603 Hamilton Hall
//     - 1:10 - 3:00 will be lecture on material.
//     - 3:00 - 3:40 will be optional discussion, recitation, etc.
//
//
// - We will periodically cancel lectures and schedule separate team meetings with me to discuss projects, provide feedback and suggestions, etc.
//
//
// - Office Hours:
//     - TBD
//     - By appointment, as needed, as available. I typically post on Piazza when I will have extra availability.
//
//
// - Course Material:
//     - No textbook
//         - Textbooks become out of date in this rapidly changing area.
//         - Material would span several books.
//     - Lecture notes and code samples [on GitHub](https://github.com/donald-f-ferguson/E6156-Cloud-Native-Applications). Sample code is mostly JavaScript and NodeJS.
//     - References to web documents and tutorials.
//
//
// - Collaboration environments:
//     - [Piazza](https:piazza.com/columbia/fall2018/comse6156_001_2018_3topicsinsoftwareengineering)
//     - [Slack](https://join.slack.com/t/dff-columbia/shared_invite/enQtMjg0Mzk4MTQwMzQxLTZlNzk3OTZmNWE2NzNmNzViZmJlMWVmNWVlZmUxZTU5NjkwYjQ1YTdjMzA3ZTMzZDM3ZmIwYzAyYjIwYTNkZDI): Please join the channel (e6156)
//
//
// - Grading:
//     - Based on final project, including project presentation. 4-5 person teams.
//     - Mandatory interim checkpoints and presentations, approximately every two weeks.
//     - Meeting instructor defined project requirements is an "A."
//
//
// - Environment:
//     - Required: AWS (team) free [tier account](https://aws.amazon.com/free/?sc_channel=PS&sc_campaign=acquisition_US&sc_publisher=google&sc_medium=ACQ-P%7CPS-GO%7CBrand%7CSU%7CCore%7CCore%7CUS%7CEN%7CText&sc_content=Brand_Free_e&sc_detail=amazon%20free%20tier&sc_category=core&sc_segment=280392800801&sc_matchtype=e&sc_country=US&sc_kwcid=AL!4422!3!280392800801!e!!g!!amazon%20free%20tier&s_kwcid=AL!4422!3!280392800801!e!!g!!amazon%20free%20tier&ef_id=WKzT_wAAAJllO8d4:20180811135240:s).
//     - Recommended:
//         - WebStorm (free student licenses https://www.jetbrains.com/student/) and/or PyCharm.
//         - Ananconda to read Jupyter Notebooks for lectures (https://www.anaconda.com/download/#macos).
//         - JavaScript kernel plug-in for Jupyter Notebooks (https://github.com/n-riesco/ijavascript).

// %% [markdown]
// ## Course Topics
//
// ### Microservices
//
// "A 'microservice' is a software development technique—a variant of the service-oriented architecture (SOA) architectural style that structures an application as a collection of loosely coupled services. In a microservices architecture, services are fine-grained and the protocols are lightweight. The benefit of decomposing an application into different smaller services is that it improves modularity and makes the application easier to understand, develop, test, and more resilient to architecture erosion. It parallelizes development by enabling small autonomous teams to develop, deploy and scale their respective services independently. It also allows the architecture of an individual service to emerge through continuous refactoring. Microservices-based architectures enable continuous delivery and deployment." (https://en.wikipedia.org/wiki/Microservices)
//
// __Note:__ <span style="color:red;">I often cut and paste definitions from Wikipedia. Wikipedia is not normative and is one of many views on any topic. The pages are a good overview and launching point for more details. Plus, if you can use Github for code and solutions, I can cut and paste text.</span>
//
// Why microservices?
// - Will cover the technical benefits in next lecture.
//
//
// - Hot, foundational technology and mastering it benefits your career.
//
// | <img src="./images/microservice_adoption.jpeg"> |
// | :---: |
// | [Microservices Architecture Market Research Report-Global Forecast 2023](https://www.marketresearchfuture.com/reports/microservices-architecture-market-3149) |
//
//
//
// | <img src="./images/microservices-2015.jpeg"> |
// | :---: |
// | [Microservice Adoption 2015](https://www.nginx.com/resources/library/app-dev-survey/)

// %% [markdown]
// ### Cloud Application/Computing
//
// #### Concept

// %% [markdown]
// "Cloud computing is an information technology (IT) paradigm that enables ubiquitous access to shared pools of configurable system resources and higher-level services that can be rapidly provisioned with minimal management effort, often over the Internet. Cloud computing relies on sharing of resources to achieve coherence and economies of scale, similar to a public utility." (https://en.wikipedia.org/wiki/Cloud_computing)
//
//
// | <img src="https://upload.wikimedia.org/wikipedia/commons/b/b5/Cloud_computing.svg"> |
// | :--: |
// | [Cloud Computing](https://en.wikipedia.org/wiki/Cloud_computing)|
//
// - NIST Conceptual Model:
//     - National Institute of Standards and Technology (NIST) defined a conceptual model for [cloud computing.](https://ws680.nist.gov/publication/get_pdf.cfm?pub_id=909505)
//     - Somewhat date and conceptual, which means the ideas matter but no one directly realizes the architecture.
//
// | <img src="./images/nist-cloud.jpeg" > |
// | :---: |
// | __NIST Cloud Concetual Model__ |
//
// - NIST Terminology:
//     - _Infrastructure-as-a-Service:_ "The capability provided to the consumer is to provision
// processing, storage, networks, and other fundamental computing resources where the
// consumer is able to deploy and run arbitrary software, which can include operating
// systems and applications. The consumer does not manage or control the underlying cloud
// infrastructure but has control over operating systems, storage, and deployed applications;
// and possibly limited control of select networking components (e.g., host firewalls)."<br><br>
//     - _Platform-as-a-Service:_ "The capability provided to the consumer is to deploy onto the cloud
// infrastructure consumer-created or acquired applications created using programming languages, libraries, services, and tools supported by the provider.3 The consumer does
// not manage or control the underlying cloud infrastructure including network, servers,
// operating systems, or storage, but has control over the deployed applications and possibly
// configuration settings for the application-hosting environment." <br><br>
//     - _Software-as-a-Service:_ The capability provided to the consumer is to use the provider’s
// applications running on a cloud infrastructure. The applications are accessible from
// various client devices through either a thin client interface, such as a web browser (e.g.,
// web-based email), or a program interface. The consumer does not manage or control the
// underlying cloud infrastructure including network, servers, operating systems, storage, or
// even individual application capabilities, with the possible exception of limited userspecific
// application configuration settings.
//
// | <img src="./images/cloud_computing_layers.jpeg"> |
// | :---: |
// | [Cloud Computing Layers](https://slideplayer.com/slide/4582525/) |

// %% [markdown]
// Some additional concepts:<br>
// - _Mobile "backend" as a service (MBaaS):_ In the mobile "backend" as a service (m) model, also known as backend as a service (BaaS), web app and mobile app developers are provided with a way to link their applications to cloud storage and cloud computing services with application programming interfaces (APIs) exposed to their applications and custom software development kits (SDKs). Services include user management, push notifications, integration with social networking services and more. This is a relatively recent model in cloud computing,[74] with most BaaS startups dating from 2011 or later but trends indicate that these services are gaining significant mainstream traction with enterprise consumers.<br><br>
//
// - _Serverless computing:_ Serverless computing is a cloud computing code execution model in which the cloud provider fully manages starting and stopping virtual machines as necessary to serve requests, and requests are billed by an abstract measure of the resources required to satisfy the request, rather than per virtual machine, per hour. Despite the name, it does not actually involve running code without servers. Serverless computing is so named because the business or person that owns the system does not have to purchase, rent or provision servers or virtual machines for the back-end code to run on.<br><br>
//
// - _Function as a service (FaaS):_ Function as a service (FaaS) is a service-hosted remote procedure call that leverages serverless computing to enable the deployment of individual functions in the cloud that run in response to events. FaaS is included under the broader term serverless computing, but the terms may also be used interchangeably.

// %% [markdown]
// <img src="./images/lecture1/Slide25.jpg" width="150%">
// <img src="./images/lecture1/Slide26.jpg" width="150%">
// <img src="./images/lecture1/Slide27.jpg" width="150%">
// <img src="./images/lecture1/Slide28.jpg" width="150%">

// %% [markdown]
// #### \*-As-a-Service in General
//
// <img src="./images/lecture1/Slide29.jpg" width="150%">

// %% [markdown]
// #### Cloud(s) We Will Use
//
// - Amazon Web Services will be the realization of most technical concepts (e.g. serverless, pub/sub).
//
//
// - AWS is the dominant public cloud platform, but other vendors are becoming significant.
//
//
// - __Concepts are what is important; you can master any realization once you understand the concepts.__
//
//
// - Will try to factor in other cloud providers, e.g. Google.
//
// |<img src="./images/Public-Cloud-Adoption-2018-vs-2017.png">|
// | :---: |
// | [Cloud Provider Adoption](https://www.rightscale.com/blog/cloud-industry-insights/cloud-computing-trends-2018-state-cloud-survey) |

// %% [markdown]
// ## How Does this Come Together: Cloud and Microservice?
//
// - IaaS provides the "hardware" in shared, scalable, elastic model consumable in chunks, usually _virtual machines_ or _containers._<br><br>
// - PaaS is prebuilt, prepackaged, application enablement and delivery software for building microservices.<br><br>
// - IaaS provides "right size" independent, virtual machines/containers to execute the microservice and supporting SW.<br><br>
// - SaaS is a complete, customizable, configurable solution to a problem, with an internal implementation that is a set of cooperating microservices.<br><br>
// - SaaS offers a user interface and APIs. New applications built as microservices on PaaS rely heavily on calling SaaS APIs and APIs into other forms of *aaS.

// %% [markdown]
// ## Sparq/Seeka Demo and Overview
//
// - Demo
//
//
// - Multi-tenancy
//
//
// - Architecture

// %% [markdown]
// | <img src="./images/serverless/Slide07.jpg" width="150%"> |
// | :---: |
// | __Sparq/Seeka__ |

// %% [markdown]
// | <img src="./images/serverless/Slide10.jpg" width="150%"> |
// | :---: |
// | __Sparq/Seeka__ |

// %% [markdown]
// ## First Microservice
//
// - __Enough talking!__
//
//
// - __We will go over microservice architecture, benefits, design patterns, yada yada ... in future lectures.__
//
// <br><br>
// <div class="cool">__Let's build a microservice. Code rules and slides drool!</div>__
// <br><br>

// %% [markdown]
// ### Application Overview
//
// | <img src="./images/web_app_layers.jpg"> |
// | :---: |
// | __Microservice/Web App Layers__ |

// %% [markdown]
// ### Setup
//
// 1. Installed
//     1. NodeJS (https://nodejs.org/en/download/).
//     2. MySQL and MySQL Workbench (https://dev.mysql.com/downloads/installer/)
//     3. WebStorm Integrated Development Environment
// <br><br>
// 2. Create directory/project
//     1. Create directory where you want your code.
//     2. Install and set up Express -- Node.JS Application Framework (https://expressjs.com/en/starter/installing.html)
//     <br><br>
// 3. Download static web site template.
//     1. I chose [Bootstrap](https://blackrockdigital.github.io/startbootstrap-small-business/) and prebuilt [SMB Template.](https://blackrockdigital.github.io/startbootstrap-small-business/)
//     2. Downloaded and copied to "static content" directory in project.

// %% [markdown]
// | <img src="./images/smbui1.jpeg"> |
// | :---: |
// | __Simple Project Homepage__ |
// <br>
//
// | <img src="./images/proj1-struct.jpeg"> |
// | :---: |
// | __Simple Project Structure__ |

// %% [markdown]
// ### Application Design Methodology: Data-Out/UX-In
//
// | <img src="./images/e6156-Slides-50.jpg"> |
// | :---: |
// | __Data-Out/UX-In Design__ |
//
// <br><br>
// __We will use data out for the first step.__

// %% [markdown]
// ### Data
//
// |<img src="./images/first_project_dm_1.jpeg"> |
// | :--: |
// | __ER Diagram $-$ Physical Model__

// %% [markdown]
// <br><br>
// __Relational Database Table Schema__
// ```
// CREATE TABLE `customers` (
//   `customers_id` varchar(12) NOT NULL,
//   `customers_lastname` varchar(64) NOT NULL,
//   `customers_firstname` varchar(64) NOT NULL,
//   `customers_email` varchar(128) NOT NULL,
//   `customers_status` enum('ACTIVE','PENDING','DELETED','SUSPENDED','LOCKED') NOT NULL,
//   `customers_password` varchar(512) NOT NULL,
//   `customers_last_login` bigint(20) NOT NULL,
//   `customers_created` bigint(20) NOT NULL,
//   `customers_modified` bigint(20) NOT NULL,
//   `tenant_id` varchar(16) NOT NULL,
//   PRIMARY KEY (`customers_id`)
// ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
//
// ```

// %% [markdown]
// Why a relational database?
// - I am lazy and can reuse code between both my classes.
//
//
// - Very common approach to managing data.
//
//
// - Good place to start.
//
//
// - A lot of application scenarios are _microservice-ify an existing (relational) data model._
//
// | <img src="./images/dbtype-percentage.jpeg"> |
// | :---: |
// | [DBMS popularity broken down by database model](https://db-engines.com/en/ranking_categories) |

// %% [markdown]
// ### Best Practice $-$ Data Access Encapsulation
//
// "In computer software, a data access object (DAO) is an object that provides an abstract interface to some type of database or other persistence mechanism. By mapping application calls to the persistence layer, the DAO provides some specific data operations without exposing details of the database. This isolation supports the single responsibility principle. It separates what data access the application needs, in terms of domain-specific objects and data types (the public interface of the DAO), from how these needs can be satisfied with a specific DBMS, database schema, etc. (the implementation of the DAO)." (https://en.wikipedia.org/wiki/Data_access_object)
//
// "The single responsibility principle is a computer programming principle that states that every module or class should have responsibility over a single part of the functionality provided by the software, and that responsibility should be entirely encapsulated by the class." (https://en.wikipedia.org/wiki/Single_responsibility_principle)
//
// | <img src="./images/dao.png"> |
// | :---: |
// | [Data Access Object](http://www.informit.com/articles/article.aspx?p=1398621&seqNum=3)

// %% [markdown]
// "..., it is a custom <br>
// More honour'd in the breach than the observance."<br>
// [Hamlet.](https://en.wikipedia.org/wiki/Hamlet)
//
// Comments:
// - There are many, many variations of this pattern and supporting frameworks.
//
//
// - Teams and organizations pick one (or write one) and then apply the pattern.
//
//
// - If you sprinkle data access code in your microservice "business logic," I will make changing schema and database backends part of the assignment until you learn your lesson.
//
//
// - I am just going to do a simple implementation.

// %%
/**
 * Created by donaldferguson on 8/12/18.
 */
let path_base = "/Users/donaldferguson/Dropbox/ColumbiaCourse/Courses/Fall2018/E6156/Projects/CustomerV2/";
let logging = require(path_base + "lib/logging");
let mysql = require('mysql');

// %%
class Dao {

    constructor(config) {
        this.config = config;
        this.db_con = null;
    }

    sayHello() {
        console.log("config = " + JSON.stringify(this.config,null,4));
    }

    execute_query(statement, values, context) {

        config = this.config;

        return	new Promise(function(resolve, reject) {
            logging.debug_message("execute_query (enter), statement = " + statement);
            logging.debug_message("values = ", values);

            var		con		=	mysql.createConnection(config.db_connect_info);

            logging.debug_message("db.execute_query: After calling con create.");

            con.connect(function(err) {
                if (err) {
                    logging.error_message("DB Connect Failed, ");
                    reject(err);			//	Return the promise error.
                }
                else {
                    logging.debug_message('Connected to DB');

                    con.query(statement, values, function(err,result){		//	Execute the query.
                        if (err) {
                            logging.debug_message("Query failed with error = ", err);
                            con.end();
                            reject(err);
                        }
                        else {
                            //logging.debug_message("Query statement = " + statement + "succeeded, rows = ", result);
                            logging.debug_message("db.execute_query: After query, result = " + JSON.stringify(result, null, 2));
                            con.end();
                            resolve(result);						//	Return the response as promised.
                        }
                    });
                }
            });
        });
    }

    get_by_id(id) {
        let sql_statement = "SELECT * FROM " + this.config.data_table +
            " where " + this.config.primary_key + " = ? ";
        return this.execute_query(sql_statement, [id], null);
    }
    
    get_by_template(tmpl) {
        // TBD
    }
    
    create(data) {
        // TBD
    }
    
    update(data) {
        // TBD
    }
    
    delete(id) {
        // TBD 
        
    }
    
    


}

// %%
    let	config = {
        db_connect_info: {
            host: "localhost",
            user: "dbuser",
            password: "dbuser"
        },
        data_table: "e6156.customers",
        primary_key: "customers_id"
    };


let d = new Dao(config);
d.sayHello();
d.get_by_id('DoFe19').then(
    function(data) {
        "use strict";
        logging.debug_message("Data = ", data)
    }
);
// Out:
// config = {
//     "db_connect_info": {
//         "host": "localhost",
//         "user": "dbuser",
//         "password": "dbuser"
//     },
//     "data_table": "e6156.customers",
//     "primary_key": "customers_id"
// }
// execute_query (enter), statement = SELECT * FROM e6156.customers where customers_id = ?
// values =  [
//   "DoFe19"
// ]
// db.execute_query: After calling con create.
// Connected to DB
// db.execute_query: After query, result = [
//   {
//     "customers_id": "DoFe19",
//     "customers_lastname": "Ferguson",
//     "customers_firstname": "Donald",
//     "customers_email": "dff@cs.columbia.edu",
//     "customers_status": "PENDING",
//     "customers_password": "sha1$8d8e1855$1$852756c072f53de81197064623ba8f75af808bc9",
//     "customers_last_login": 0,
//     "customers_created": 1536178595511,
//     "customers_modified": 1536178595511,
//     "tenant_id": "E6156"
//   }
// ]
// Data =  [
//   {
//     "customers_id": "DoFe19",
// ...

// %% [markdown]
// __Questions?__
//
// ![image.png](attachment:image.png)

// %% [markdown]
// ### Unpacking the Code Exposes Some Critical Concepts
//
// - These concepts, if you do not already understand them, are necessary before any serious coding.
//
//
// - Specifically,
//     - "Connections"
//     - Asynchronous programming.
//
// #### Database Connection
//
// ##### Core Concept
//
// | ![image.png](attachment:image.png) |
// | :---: |
// | __Database Connection__ |
//
// "In computer science, a database connection is the means by which a database server and its client software communicate with each other. The term is used whether or not the client and the server are on different machines." (https://en.wikipedia.org/wiki/Database_connection)
//
// - Database systems and products provide client libraries and SDKs that simplify using the database APIs.
//
// ```
// let	config = {
//     db_connect_info: {
//         host: "localhost",
//         user: "dbuser",
//         password: "dbuser"
//     },
//     data_table: "e6156.customers",
//     primary_key: "customers_id"
// };
// ```
//
// In this simple example, the connection information is:
// - Host (Internet location of the database server)
//
//
// - User and password to associate with requests on this connection (authentication, authorization)
//
//
// - There are many other "command and control" properties associated with a connection.

// %% [markdown]
// Changing the connection:
// - I made a similar database on [Amazon Relational Data Service](https://aws.amazon.com/rds/)
//
//
// - Created a table.

// %% [markdown]
// ![image.png](attachment:image.png)

// %%
config4 = {
    db_connect_info: {
        host: "columbiae6156.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
        user: "dbuser2",
        password: "dbuser2"
    },
    data_table: "cloude6156.customers",
    primary_key: "customers_id"
};

d4 = new Dao(config4);
d4.get_by_id('dv1');
// Out:
// execute_query (enter), statement = SELECT * FROM cloude6156.customers where customers_id = ?
// values =  [
//   "dv1"
// ]
// db.execute_query: After calling con create.
// Connected to DB
// db.execute_query: After query, result = [
//   {
//     "customers_id": "dv1",
//     "customers_lastname": "Vader",
//     "customers_firstname": "Darth",
//     "customers_email": "dv@ds.rog",
//     "customers_status": "ACTIVE",
//     "customers_password": "NONE",
//     "customers_last_login": 0,
//     "customers_created": 0,
//     "customers_modified": 0,
//     "tenant_id": ""
//   }
// ]
// [ RowDataPacket {
//     customers_id: 'dv1',
//     customers_lastname: 'Vader',
//     customers_firstname: 'Darth',
//     customers_email: 'dv@ds.rog',
//     customers_status: 'ACTIVE',
//     customers_password: 'NONE',
//     customers_last_login: 0,
//     customers_created: 0,
//     customers_modified: 0,
//     tenant_id: '' } ]

// %% [markdown]
// ##### FYI $-$ Database Connection Pool
//
// | <img src="./images/db_connection_pool.png"> |
// | :---: |
// | __Web/Internet Application Structure__ |
//
// - An application server can be supporting a large number of users.
//
//
// - At any point in time, the application server can be processing many active requests.
//
//
// - Database engine performance degrades:
//     - If there are a large number of active connections.
//     - Connections are created and released frequently.
//
//
// - Application server environments introduce the concept of a _connection pool._

// %% [markdown]
// | ![image.png](attachment:image.png) |
// | :---: |
// | __Connection Pool__ |
//
// - The connection pool manages a set of reusable connections.
//
//
// - Application code _requests_ a connection.
//
//
// - The connection pool manager:
//     - Returns a previously created connection, if one is available.
//     - Queues/blocks the request until an active request releases a connection.
//
//
// - Significantly more efficient than allowing application code to directly create/release connections.
//
//
// - This is FYI. Do not worry about the concept, but know that it exists and that the pattern applies in many scenarios in which application code connects/disconnects from a service.

// %% [markdown]
// ##### Generalization
//
// - The concept of "connection" is more general than databases.
//
//
// - Elements of the concept appear in many places, e.g. REST APIs.

// %% [markdown]
// ##### A Note on Security
//
// - In real applications, you would __NEVER PUT USERIDs OR PASSWORDS IN SOURCE CODE.__
//
//
// - There are various techniques for configuring an environment so that applications can get necessary credentials.
//     - These are very environment specific.
//     - This is not a security class, but we will see some examples with AWS. Other cloud and on-premise platforms have analogous mechanisms.

// %% [markdown]
// #### Asynchronous Operations, Callbacks and Promises
//
// - Some statements can "take a long time."
//
//
// - The database call ```con.query(statement)```
//     - Sends a network message to a remote system.
//     - The remote system validates the input, performs the operation and sends a network response.
//     - Processing the operation may require disk IOs or other "slow" operations.
//
//
// - Freezing/blocking the application server while a remote operation is in progress is inefficient and prevents processing requests from other active clients.
//
//
// - There are two solutions to enable a server to continue processing requests when an application make a "slow" call:
//     - Multi-threading.
//     - Callbacks/events.
//
// | ![image.png](attachment:image.png) |
// | :---: |
// | __Multithreading and Callbacks__ |

// %% [markdown]
// <br>
// - JavaScript's model is single threaded with callbacks, both in the browser and Node.JS runtime.
//
//
// - This can lead to some odd behavior if you are a Java or Python programmer until you get used to it.

// %%
call_back = function(err, result) {
    var d = new Date();
    logging.debug_message(d + "Fast: After query, result = ", result);
}
call_back_slow = function(err, result) {
    var d = new Date();
    logging.debug_message(d + "Slow: After query, result = ", result);
}

con_slow = mysql.createConnection(
    {
        host: "columbiae6156.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
        user: "dbuser2",
        password: "dbuser2"
    });

con_slow.connect(function(err) {
    if (err) {
        logging.error_message("DB Connect Failed, ");
        logging.debug_message("Error = ", err);			//	Return the promise error.
    }
    else {
        logging.debug_message("Slow: Connected!!!");
        con_slow.query("SELECT * FROM cloude6156.customers", call_back_slow)
    }
});

con = mysql.createConnection(
    {
        host: "localhost",
        user: "dbuser",
        password: "dbuser"
    });


con.connect(function(err) {
    if (err) {
        logging.error_message("DB Connect Failed, ");
        logging.debug_message("Error = ", err);			//	Return the promise error.
    }
    else {
        logging.debug_message("Connected!!!");
        con.query("SELECT * FROM e6156.customers;", call_back)
    }
});


logging.debug_message("This statement is after the statements above but seems to execute " +
                      "before the preceding statements. Even the loop complete before the statements above.\n\n");
for (i = 0; i < 10; i++) {
    logging.debug_message("i = ", i)
}
// Out:
// evalmachine.<anonymous>:12
// con_slow = mysql.createConnection(
// ^
//
// ReferenceError: mysql is not defined
//     at evalmachine.<anonymous>:12:1
//     at ContextifyScript.Script.runInThisContext (vm.js:50:33)
//     at Object.runInThisContext (vm.js:139:38)
//     at run ([eval]:1002:15)
//     at onRunRequest ([eval]:829:18)
//     at onMessage ([eval]:789:13)
//     at emitTwo (events.js:126:13)
//     at process.emit (events.js:214:7)
//     at emit (internal/child_process.js:772:12)
//     at _combinedTickCallback (internal/process/next_tick.js:141:11)

// %% [markdown]
// - Observations
//     - Code appears to not execute in defined order.
//     - Loop and print statement seem to execute first.
//     - "Slow" database accessed first but produces results after "fast" database.

// %% [markdown]
// - JavaScript requires callbacks, which can result in "Callback H\*ll," will results in deeply nested code, aka "The Pyramid of Doom."
//
// | ![image.png](attachment:image.png) |
// | :---: |
// | __Pyramid of Doom__ |

// %% [markdown]
// - A (supposedly) cleaner solution is _Promises._
//
// | <img src="./images/e6156-f18-lecture-1-55.jpg"> |
// | :---: |
// | [Callback and Promises]() |

// %% [markdown]
// - There is a "promisified" mysql package [promise-mysql](https://www.npmjs.com/package/promise-mysql)

// %%
//let path_base = "/Users/donaldferguson/Dropbox/ColumbiaCourse/Courses/Fall2018/E6156/Projects/FirstMicroservice/";
//let logging = require(path_base + "lib/logging");
var mysqlp = require('promise-mysql');

x = mysqlp.createConnection({
    host: 'localhost',
    user: 'dbuser',
    password: 'dbuser'
}).then(function(conn){
    var result = conn.query('select * from e6156.customers');
    conn.end();
    return result;
}).then(function(rows){
    // Logs out a list of hobbits
    console.log(rows);
});

console.log("Done.");
// Out:
// Done.
// [ RowDataPacket {
//     customers_id: 'DoFe19',
//     customers_lastname: 'Ferguson',
//     customers_firstname: 'Donald',
//     customers_email: 'dff@cs.columbia.edu',
//     customers_status: 'PENDING',
//     customers_password: 'sha1$8d8e1855$1$852756c072f53de81197064623ba8f75af808bc9',
//     customers_last_login: 0,
//     customers_created: 1536178595511,
//     customers_modified: 1536178595511,
//     tenant_id: 'E6156' } ]

// %%
//let path_base = "/Users/donaldferguson/Dropbox/ColumbiaCourse/Courses/Fall2018/E6156/Projects/FirstMicroservice/";
//let logging = require(path_base + "lib/logging");
//var mysql = require('promise-mysql');

// Get a promise that is called when the connect completes.
fastC = mysqlp.createConnection({
    host: 'localhost',
    user: 'dbuser',
    password: 'dbuser'
});

// Ditto, but for the slow connection.
slowC = mysqlp.createConnection(
    {
        host: "columbiae6156.cqgsme1nmjms.us-east-1.rds.amazonaws.com",
        user: "dbuser2",
        password: "dbuser2"
    });

// Get a promise that resolves when ALL of the promises in the list
// complete. The individual "things" run in "parallel."
y = Promise.all([fastC, slowC]).then(
    
    // This function is called with an array of "results" when all promises
    // have completed. This will be an array of connections.
    function(results) {
        "use strict";
        logging.debug_message("Both connections completed!");
        
        // Let's make some promises to run the queries.
        let fastA = results[0].query("select * from e6156.customers;")
        let slowA = results[1].query("select * from cloude6156.customers;");
        
        // Close the connection when done.
        results[0].end();
        results[1].end();
        
        // A promise that resolves when all of the queries resolve.
        return Promise.all([fastA, slowA])
    }
);

// When all of the promises are resolved, we get an array of results.
y.then(
    function(results) {
        "use strict";
        for (var i = 0; i < results.length; i++) {
            logging.debug_message("Database[" + i + "] returned ", results[i]);
        }
    });
// Out:
// Both connections completed!
// Database[0] returned  [
//   {
//     "customers_id": "DoFe19",
//     "customers_lastname": "Ferguson",
//     "customers_firstname": "Donald",
//     "customers_email": "dff@cs.columbia.edu",
//     "customers_status": "PENDING",
//     "customers_password": "sha1$8d8e1855$1$852756c072f53de81197064623ba8f75af808bc9",
//     "customers_last_login": 0,
//     "customers_created": 1536178595511,
//     "customers_modified": 1536178595511,
//     "tenant_id": "E6156"
//   }
// ]
// Database[1] returned  [
//   {
//     "customers_id": "df1",
//     "customers_lastname": "Ferguson",
//     "customers_firstname": "Donald",
//     "customers_email": "dff9@columbia.edu",
//     "customers_status": "ACTIVE",
//     "customers_password": "None",
//     "customers_last_login": 0,
//     "customers_created": 0,
//     "customers_modified": 0,
//     "tenant_id": "E6156"
//   },
//   {
//     "customers_id": "dv1",
//     "customers_lastname": "Vader",
// ...

// %% [markdown]
// #### Let's Wrap this Up and Move On
//
// - The traditional programming that most of you have learned focuses on _control flow._
//     - x = f(y)
//     - if ... then ...
//     - for (...)
//     - switch(...)
//
//
// - In addition to the simple control flow, microservice/cloud programming
//     - Is extremely _asynchronous_
//     - Relies heavily on "composing" asynchronous operations using events, promises, await, ...
//     - And this can be very confusing in the beginning.

// %% [markdown]
// ## Next Steps
//
// - This was an unusual lecture.
//
//
// - We went from some very, very high level statements like "Cloud good."
//
//
// - To deep in the guts of connections and promises.
//
//
// - I did this two level approach because:
//     - Understanding the course and technology landscape is important when starting.
//     - Understanding connections, threading and asynchronous programming is critical in this space.
//         - I have observed in the past that students are not aware of the concept and struggle in the beginning.
//         - I want you to be prepared when you get started, but will help with details going forward.
//
//
// - We will pull this all together in the next lecture when we build our 1st microservice and deploy on a cloud.
//
//
// - Your "homework"
//     1. <span style="color:red;">Have your teams formed (4-5 people) by next lecture.</span>
//     2. Configure and set up your environments.
//     3. __Play around with Node JS, databases, etc.__
//     4. __Write some simple code that connects to an RDB and runs some queries.__
//     4. Join collaboration environments.
